# %% [markdown]
# # Pandas Import

# %%
import pandas as pd

# %%
#pd.read_excel('file.csv',sheet_name=,)

# %%
pd.read_csv('question_answer_pairs.txt',sep='\t')
# Out:
#          ArticleTitle                                           Question  \
# 0     Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 1     Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 2     Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 3     Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 4     Abraham_Lincoln                   Did his mother die of pneumonia?
# ...               ...                                                ...
# 1710   Woodrow_Wilson  Was Wilson president of the American Political...
# 1711   Woodrow_Wilson  Did he not cast his ballot for John M. Palmer ...
# 1712   Woodrow_Wilson  Did Wilson not spend 1914 through the beginnin...
# 1713   Woodrow_Wilson  Was Wilson , a staunch opponent of antisemitis...
# 1714   Woodrow_Wilson                             What happened in 1917?
#
#                                                  Answer  \
# ...

# %% [markdown]
# # ``JSON``

# %%
import pandas as pd

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# # Working With SQL

# %%
# !pip install mysql.connector
# Out:
# ...
# WARNING: Ignoring invalid distribution -yio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1yio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0yio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
import mysql.connector

# %%
conn=mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_sql_query(
    "SELECT * FROM  Country where Name LIKE 'Aruba'"
    ,conn)
# Out:
#   Code   Name      Continent     Region  SurfaceArea IndepYear  Population  \
# 0  ABW  Aruba  North America  Caribbean        193.0      None      103000
#
#    LifeExpectancy    GNP  GNPOld LocalName  \
# 0            78.4  828.0   793.0     Aruba
#
#                                  GovernmentForm HeadOfState  Capital Code2
# 0  Nonmetropolitan Territory of The Netherlands     Beatrix      129    AW

# %% [markdown]
# # Pandas Export
# - to_csv
# - to_excel
# - to_html
# - to_json
# - to_sql

# %%
import pandas as pd
df = pd.DataFrame()

# %%
df.to
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # to_csv

# %%
df = pd.read_csv('ipl_deliveries.csv')
df.head()
# Out:
#         ID                            Team  innings  overs  ballnumber  \
# 0  1312200  Rajasthan RoyalsGujarat Titans        1      0           1
# 1  1312200  Rajasthan RoyalsGujarat Titans        1      0           2
# 2  1312200  Rajasthan RoyalsGujarat Titans        1      0           3
# 3  1312200  Rajasthan RoyalsGujarat Titans        1      0           4
# 4  1312200  Rajasthan RoyalsGujarat Titans        1      0           5
#
#         batter          bowler  non-striker extra_type  batsman_run  \
# 0  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 1  YBK Jaiswal  Mohammed Shami   JC Buttler    legbyes            0
# 2   JC Buttler  Mohammed Shami  YBK Jaiswal        NaN            1
# 3  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 4  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
#
#    extras_run  total_run  non_boundary  isWicketDelivery player_out kind  \
# ...

# %%
temp = df.groupby('batter')['batsman_run'].sum().reset_index()

# %%
temp.to_csv('batsman_run.csv',index=False)

# %% [markdown]
# # to_excel

# %%
temp.to_excel('bat.xlsx',index=False)

# %%
temp.to_excel('bat.xlsx',sheet_name='First')

# %%
temp.to_excel('bat.xlsx',sheet_name='Second')

# %%
temp_1=df.pivot_table(index='batter',columns='BowlingTeam',values='batsman_run',aggfunc='sum')

# %% [markdown]
# **when you have ``multiple sheets``**

# %%
with pd.ExcelWriter('output.xlsx') as writer:
    temp.to_excel(writer,sheet_name='First')
    temp_1.to_excel(writer,sheet_name='Second')

# %% [markdown]
# **``or``**

# %%
writer = pd.ExcelWriter('final.xlsx')
temp.to_excel(writer,'original')
temp_1.to_excel(writer,'result')
writer.save()

# %% [markdown]
# # to_html

# %%
df.query('batsman_run==6').pivot_table(index='overs',columns='ballnumber',values='batsman_run',aggfunc='count').to_html('sixes_heatmap.html')

# %% [markdown]
# # to_json

# %%
df.groupby(['BattingTeam','batter'])['batsman_run'].sum().unstack().to_json('ipl.json')

# %% [markdown]
# # to_sql

# %%
import pymysql
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:@localhost/ipl')
# {root}:{password}@{url}/{database}
df.to_sql('ipl_delivery',con=engine,if_exists='append')

# %%
# 2nd table
temp.to_sql('batsman_run',con=engine,if_exists='append')
